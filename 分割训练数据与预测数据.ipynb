# %%
import pandas as pd
import numpy as np

import warnings

# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt

import seaborn as sns
sns.set(color_codes=True)
import json

warnings.filterwarnings('ignore')
import sklearn as sk

import xgboost as xgb 
import lightgbm as gbm
import catboost as cat

import tpot

# %%
df = pd.read_csv(r'C:\Users\Admin\Desktop\泰迪杯\泰迪杯\5f0bd422931fa901bf76b22aea303a8f\附件2.csv')

# %%
df
# Out:
#        TICKER_SYMBOL  ACT_PUBTIME  PUBLISH_DATE  END_DATE_REP  END_DATE  \
# 0               4019            3             3             2         1
# 1               8166            3             3             2         1
# 2               9063            3             3             2         1
# 3              10083            4             4             4         1
# 4              11737            3             3             2         1
# ...              ...          ...           ...           ...       ...
# 22208        4993201            7             7             7         6
# 22209        4993297            7             7             7         6
# 22210        4997833            7             7             7         6
# 22211        4998808            7             7             7         6
# 22212        4999709            7             7             7         6
#
#       REPORT_TYPE  FISCAL_PERIOD  MERGED_FLAG ACCOUTING_STANDARDS CURRENCY_CD  \
# ...

# %%
df.loc[df['TICKER_SYMBOL']==4019]
# Out:
#        TICKER_SYMBOL  ACT_PUBTIME  PUBLISH_DATE  END_DATE_REP  END_DATE  \
# 0               4019            3             3             2         1
# 3094            4019            4             4             3         2
# 6555            4019            5             5             4         3
# 10118           4019            6             6             5         4
# 13908           4019            7             7             6         5
# 18060           4019            7             7             7         6
#
#       REPORT_TYPE  FISCAL_PERIOD  MERGED_FLAG ACCOUTING_STANDARDS CURRENCY_CD  \
# 0               A             12            1           CHAS_2007         CNY
# 3094            A             12            1           CHAS_2007         CNY
# 6555            A             12            1           CHAS_2007         CNY
# 10118           A             12            1           CHAS_2007         CNY
# ...

# %%
df.iloc[18060:,:]
# Out:
#        TICKER_SYMBOL  ACT_PUBTIME  PUBLISH_DATE  END_DATE_REP  END_DATE  \
# 18060           4019            7             7             7         6
# 18061           4213            7             7             7         6
# 18062           8166            7             7             7         6
# 18063           9063            7             7             7         6
# 18064          10083            7             7             7         6
# ...              ...          ...           ...           ...       ...
# 22208        4993201            7             7             7         6
# 22209        4993297            7             7             7         6
# 22210        4997833            7             7             7         6
# 22211        4998808            7             7             7         6
# 22212        4999709            7             7             7         6
#
#       REPORT_TYPE  FISCAL_PERIOD  MERGED_FLAG ACCOUTING_STANDARDS CURRENCY_CD  \
# ...

# %%
df_predict = df.iloc[18060:,:]

# %%
df_predict
# Out:
#        TICKER_SYMBOL  ACT_PUBTIME  PUBLISH_DATE  END_DATE_REP  END_DATE  \
# 18060           4019            7             7             7         6
# 18061           4213            7             7             7         6
# 18062           8166            7             7             7         6
# 18063           9063            7             7             7         6
# 18064          10083            7             7             7         6
# ...              ...          ...           ...           ...       ...
# 22208        4993201            7             7             7         6
# 22209        4993297            7             7             7         6
# 22210        4997833            7             7             7         6
# 22211        4998808            7             7             7         6
# 22212        4999709            7             7             7         6
#
#       REPORT_TYPE  FISCAL_PERIOD  MERGED_FLAG ACCOUTING_STANDARDS CURRENCY_CD  \
# ...

# %%
df_train = df.iloc[:18060,:]

# %%
df_train
# Out:
#        TICKER_SYMBOL  ACT_PUBTIME  PUBLISH_DATE  END_DATE_REP  END_DATE  \
# 0               4019            3             3             2         1
# 1               8166            3             3             2         1
# 2               9063            3             3             2         1
# 3              10083            4             4             4         1
# 4              11737            3             3             2         1
# ...              ...          ...           ...           ...       ...
# 18055        4993201            7             7             6         5
# 18056        4993297            7             7             6         5
# 18057        4997833            7             7             6         5
# 18058        4998808            7             7             6         5
# 18059        4999709            7             7             6         5
#
#       REPORT_TYPE  FISCAL_PERIOD  MERGED_FLAG ACCOUTING_STANDARDS CURRENCY_CD  \
# ...

# %%
df_predict.to_csv('C:/Users/Admin/Desktop/泰迪杯/泰迪杯/5f0bd422931fa901bf76b22aea303a8f/预测数据.csv',index = False)

# %%
df_train.to_csv('C:/Users/Admin/Desktop/泰迪杯/泰迪杯/5f0bd422931fa901bf76b22aea303a8f/训练数据.csv',index = False)
